# %% [markdown]
# Installing transformers

# %%
# !pip install transformers
# !pip install ipywidgets

# %% [markdown]
# Import statements

# %%
# Use a pipeline as a high-level helper
import os, IPython
IPython.Application.instance().kernel.do_shutdown(restart=True)
# Out:
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Grammar correction and sentimental analysis based on user input

# %%
from transformers import pipeline
import torch

def getMoodAnalysisResult(text):
    mood='Normal'
    correct = pipeline("text2text-generation", model="prithivida/grammar_error_correcter_v1")
    text = correct(text)[0]['generated_text']
    pipe = pipeline("text-classification", model="nlptown/bert-base-multilingual-uncased-sentiment")
    res = pipe(text)
    res=res[0]
    label=res['label']
    score=res['score']
    
    #logic for flagging
    if(label in ('1 star','2 stars') or (label == '3 stars' and score<=0.4)):
        mood='High Risk'
    elif((label == '3 stars' and score>0.4)):
        mood='Moderate Risk'
    elif((label == '4 stars' and score<0.4)):
        mood='Low Risk'
    else:
        mood='Normal'
    return mood

# %%
getMoodAnalysisResult("these days i just feel so tired and alon,e even wen im with people. cant sleep at nite i just keep thinkng about all the things that cud go wrong in my life nothing feels good or worth wakingup for its like im stuck in a hole")
# Out:
# Device set to use cpu
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# 'High Risk'

# %%
getMoodAnalysisResult("lol today was gr8!! finaly got the chnce to hangout w my besties after soooo long pizza and movii night the jokes we made still make me laugh so hard i wish every day cud feel this easy and fun")
# Out:
# Device set to use cpu
# Device set to use cpu
# 'Normal'

# %%
getMoodAnalysisResult("got up late 2day made omlette and tea. cleaned my room a bit and then just scrolled insta for a while. not much hapening these days feels like same thing over and over but not exactly sad")
# Out:
# Device set to use cpu
# Device set to use cpu
# 'Moderate Risk'

# %%
getMoodAnalysisResult("started with playing cricket then lunch and sat to watch the odi match")
# Out:
# Device set to use cpu
# Device set to use cpu
# 'Low Risk'
